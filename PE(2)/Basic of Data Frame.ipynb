# %%
#Name : Deep M Konde
#Roll no. : 32
#Sec : C
#Subject : ET 2

# %% [markdown]
# # Creating Series

# %%
# Program for creating Series using series() method of Pandas Library

# %%
import pandas as pd

# %%
#Creating Student Name List
Name=["Deep","Ayush","Krishna","Swaraj","Soham","Tilak"]
Name
# Out:
# ['Deep', 'Ayush', 'Krishna', 'Swaraj', 'Soham', 'Tilak']

# %%
#Creating a Series 
Roll_list=pd.Series(Name,index=[1,2,3,4,5,6])
print(Roll_list)
# Out:
# 1       Deep
# 2      Ayush
# 3    Krishna
# 4     Swaraj
# 5      Soham
# 6      Tilak
# dtype: object

# %% [markdown]
# # Creating Data Frame

# %%
#Import Pandas library
import pandas as pd

# %%
#Creating Data Frame
df=pd.DataFrame([[11,19,13,20],[11,18,15,21],[12,13,14,15]],
columns= ["SE","DSS","MLAI","SQl"])

# %%
df
# Out:
#    SE  DSS  MLAI  SQl
# 0  11   19    13   20
# 1  11   18    15   21
# 2  12   13    14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (Row) to the data frame

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns= ["SE","DSS","MLAI","SQl"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    SE  DSS  MLAI  SQl
# 0  11   19    13   20
# 1  11   18    15   21
# 2  12   13    14   15
# 3   5    6     7    8

# %% [markdown]
# # Adding Attribute (Columns) name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    SE  DSS  MLAI  SQl  DM
# 0  11   19    13   20  12
# 1  11   18    15   21  15
# 2  12   13    14   15  16
# 3   5    6     7    8  14

# %% [markdown]
# # Deleting Record from  df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    SE  DSS  MLAI  SQl  DM
# 0  11   19    13   20  12
# 2  12   13    14   15  16
# 3   5    6     7    8  14

# %% [markdown]
# # Deleting Attribute (Columns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    SE  DSS  MLAI  SQl
# 0  11   19    13   20
# 1  11   18    15   21
# 2  12   13    14   15
# 3   5    6     7    8

# %%
#Finding mean of DSS 

print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 14.0

# %%
#Finding median of DSS

print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 15.5

# %%
#Finding mode of DSS

print("Mode of DSS:", df5["DSS"].mode())
# Out:
# Mode of DSS: 0     6
# 1    13
# 2    18
# 3    19
# Name: DSS, dtype: int64

# %%
#Finding max number of DSS

print("Max of DSS:", df5["DSS"].max())
# Out:
# Max of DSS: 19

# %%
#Finding Min number of DSS

print("Max of DSS:", df5["DSS"].min())
# Out:
# Max of DSS: 6
